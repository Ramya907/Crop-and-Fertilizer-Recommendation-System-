# %% [markdown]
# import sys

# %%
def phone_store():
    store=0
    ram=0
    tot_price=0
    print("********** WELCOME TO PYTHON STORE. **********")
    
    phone= input("Do you want phone? Type Yes or No: ").lower()
    
    while phone != 'yes' and phone != 'no':
        print('You gave invalid input. Please select Yes or No')
        phone = input("Do you want a phone? Type Yes or No: ").lower()

    if phone == 'no':
        print("Okay.Thanks for visiting our store!")
        return 

    print('Great! Select the phone from the below list.')
    print('1. Apple iPhone\n2. Redmi\n3. Samsung galaxy')
    choice = input("Which Brand do you prefer? : ").lower()

#=========================== I P H O N E ======================================================
    if choice == "apple iphone" or choice == "1":
        print(" 1.iPhone 15\n 2.iPhone 15 plus\n 3.iPhone 15 Pro\n 4.iPhone 15 Pro Max")
        apple_choice=input('Which model in iphone will u prefer?').lower()
        
        if apple_choice=="iphone 15" or apple_choice=="1":
            mod="Apple iPhone 15"
            dis="6.1 inches(15.49cm);OLED 60HZ Refresh Rate"
            res="1179*2556px(FHD+)"
            cam="48MP + 12MP dual rear, 12MP front"
            bat="3349mAh, 20w fast charging"
            proc="A16 Bionic chip"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n')
            print("   VARIANT: \n 1.6gb + 128gb \n 2.6gb + 256gb \n 3.6gb + 512gb")
    
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 6
                store = 128
                tot_price += 70499
            elif storage==2:
                ram = 6
                store = 256
                tot_price += 73999
            elif storage==3:
                ram = 6
                store = 512
                tot_price += 100600    
            else:
                print("Invalid choice for storage.")
            
        elif apple_choice=="iphone 15 plus" or apple_choice=="2":
            mod="Apple iPhone 15 Plus"
            dis="6.7 inches(17.00cm)Super Retina XDR OLED Display"
            cam="Dual camera setup,48MP + 12MP wide angle primary camera,12MP front camera"
            res="1179*2556px"
            bat="3349mAh ,20w fast charging"
            proc="A16 Bionic chip"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT & RAM: \n 1.6gb + 128gb \n 2.6gb + 256gb \n 3.6gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 6
                store = 128
                tot_price += 79900
            elif storage==2:
                ram = 6
                store = 256
                tot_price += 89900
            elif storage==3:
                ram = 6
                store = 512
                tot_price += 99900
            else:
                print("Invalid choice for storage.")
    
                        
        elif apple_choice=="iphone 15 pro" or apple_choice=="3":
            mod="Apple iPhone 15 Pro"
            dis="6.1 inches(15.54cm)Super Retina XDR OLED "
            res="1179*2556px"
            cam="Dual camera setup, 48MP + 12MP wide angle primary camera,12MP front camera"
            bat="3349mAh ,20w fast charging"
            proc="A16 Bionic chip"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n')
            print("VARIANT & RAM: \n 1.6gb + 128gb \n 2.6gb + 256gb \n 3.6gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 6
                store= 128
                tot_price += 128200
            elif storage==2:
                ram = 6
                store = 256
                tot_price += 133600
            elif storage==3:
                ram = 6
                store = 512
                tot_price += 156400 
            else:
                print("Invalid choice for storage.")
    
               
        elif apple_choice=="iphone 15 pro max" or apple_choice=="4":
            mod="Apple iPhone 15 Pro Max"
            dis="6.7 inches(17.00cm)Super Retina XDR OLED Display"
            res="1179*2556px(FHD+)"
            cam="Dual camera setup ,48MP + 12MP wide angle primary camera, 12MP front cam"
            bat="3349mAh, 20w fast charging"
            proc="A16 Bionic chip"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n')
            print("VARIANT & RAM: \n  1.6gb + 256gb \n 2.6gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 6
                store = 256
                tot_price += 140990
            elif storage==2:
                ram  =  6
                store = 512
                tot_price += 166600
            else:
                print("Invalid choice for storage.")

        else:
            print('Sorry, this phone is not available')
      
#============================= R E D M I ===============================================
    
    elif choice.lower()== "redmi" or choice == "2":
        print(" 1.Redmi 12\n 2.Redmi Note 12 \n 3.Redmi 12 5G")
        redmi_choice=input('Which model in Redmi will u prefer?').lower()

            
        if redmi_choice=="redmi 12" or redmi_choice=="1":
            mod="Redmi 12"
            dis="6.79 inches FHD+90Hz LCD"
            res="1080*2460 pixels(FHD+) "
            cam="Triple Camera setup, 50MP Main + 8Mp ultra-wide + 2MP macro "
            bat="5000mAh with 18W fast charging"
            proc="MediaTek Helio G88"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT: \n 1.6gb + 128gb \n 2.8gb + 256gb \n 3.8gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 6
                store = 128
                tot_price += 9989
            elif storage==2:
                ram = 8
                store = 256
                tot_price += 13998
            elif storage==3:
                ram = 8
                store = 512
                tot_price += 15600    
            else:
                print("Invalid choice for storage.")
                

        elif redmi_choice=="redmi note 12" or redmi_choice=="2":
            mod="Redmi Note 12"
            dis="6.67 inches FHD + AMOLED ,120Hz "
            res="1080*2460 pixels(FHD+) "
            cam="Triple Camera setup, 50MP Main+ 8Mp ultra-wide, 13MP front camera "
            bat="5000mAh with 33W fast charging"
            proc="Qualcomm Snapdragon 685"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT & RAM: \n 1.4gb + 128gb \n 2.8gb + 256gb \n 3.6gb + 128gb \n 4.6gb + 64gb \n")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 4
                store = 128
                tot_price += 10990
            elif storage==2:
                ram = 8
                store = 256
                tot_price += 15999
            elif storage==3:
                ram = 6
                store = 128
                tot_price += 13499
            elif storage==4:
                ram = 6
                store = 64
                tot_price += 12900
            else:
                print("Invalid choice for storage.")
                

        elif redmi_choice=="redmi 12 5g" or redmi_choice=="3":
            mod="Redmi 12 5G"
            dis="6.79 inches FHD+90Hz LCD"
            res="1080*2460 pixels(FHD+) "
            cam="Dual Camera setup ,50MP Main + 2MP depth sensor, 12MP front camera "
            bat="5000mAh with 18W fast charging"
            proc="Qualcomm Snapdragon 4 Gen 2"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT & RAM: \n 1.8gb + 128gb \n 2.8gb + 256gb \n 3.6gb + 128gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 8
                store = 128
                tot_price += 13999
            elif storage==2:
                ram = 8
                store = 256
                tot_price += 19799
            elif storage==3:
                ram = 6 
                store = 128
                tot_price += 10599
            else:
                print("Invalid choice for storage.")
        else:
            print('Sorry, This phone is not available.')

#================================  S A M S U N G ======================================== 
    
    elif choice == "samsung galaxy" or choice == "3":
        print(" 1.Samsung Galaxy S23\n 2.Samsung Galaxy A54\n 3.Samsung Galaxy Z Fold 5")
        sam_choice=input('Which Model in Samsung you prefer: ' ).lower()
                       
        if sam_choice=="samsung galaxy s23" or sam_choice=="1":
            mod="Samsung Galaxy S23"
            dis="6.1 inch Dynamic AMOLED 2X display,120Hz refresh rate"
            res="2340*1080 pixels"
            cam="50MP Main,12Mp ultra-wide sensor,10MP telephoto lens"
            bat="900mAh with 25W fast charging"
            proc="Qualcomm Snapdragon 8 Gen 2 "
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT & RAM: \n 1.8gb + 128gb \n 2.8gb + 256gb \n 3.12gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 8
                store= 128
                tot_price += 37249
            elif storage==2:
                ram = 8
                store = 256
                tot_price += 40499
            elif storage==3:
                ram = 12
                store = 512
                tot_price += 92999
            else:
                print("Invalid choice for storage.")
        

        elif sam_choice=="samsung galaxy a54" or sam_choice=="2":
            mod="Samsung Galaxy A54"
            dis="6.4 inches AMOLED display,120Hz refresh rate "
            res="2340*1080 pixels"
            cam="50MP Main, 12MP ultra-wide, 5MP macro, 32MP Selfie Cam "
            bat="5000mAh with 25W fast charging"
            proc="Exynos 1380 chipset, mali-G68 GPU"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n')
            print("VARIANT: \n 1.8gb + 128gb \n 2.8gb + 256gb \n ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 8
                store = 128
                tot_price += 33499
            elif storage==2:
                ram = 8 
                store = 256
                tot_price += 35499
            else:
                print("Invalid choice for storage.")
    

        elif sam_choice=="samsung galaxy z fold 5" or sam_choice=="3":
            mod="Samsung Galaxy Z Fold 5"
            dis="7.6 inches Dynamic AMOLED 2X foldable display"
            res="2176*1812 pixels"
            cam="50MP Main, 12MP ultra-wide,10MP selfie camera "
            bat="400mAh with 25W fast charging"
            proc="Qualcomm Snapdragon 8 Gen 2 for Galaxy"
            print(f'\n About Phone\n DISPLAY: {dis}\n RESOLUTION: {res}\n CAMERA: {cam}\n BATTERY: {bat}\n PROCESSOR: {proc}\n ')
            print("VARIANT & RAM: \n 1.8gb + 128gb \n 2.12gb + 256gb  \n 3.12gb + 512gb ")
            storage=int(input("What storage and ram phone you need to select: "))
            if storage== 1:
                ram = 8 
                store = 128
                tot_price += 58800
            elif storage==2:
                ram = 12
                store = 256
                tot_price += 94999
            elif storage==3:
                ram = 12
                store = 512
                tot_price += 164999
            else:
                print("Invalid choice for storage.")

        else:
            print('Sorry, This Phone is not available.')
            
#===================== C O L O R S =================================
    if choice.lower() in ['1','2','3','apple iphone','redmi','samsung galaxy']:
        print("\nAvailable Colors: [Black, White, Red, Silver]")
        color = input("Which color do you prefer ?: ").lower()
        if color=='black' or color=='red' or color=='white' or color=='silver':
            print(f"You selected {color}.")
        else:
            print("Sorry, this color is not available.")
            color = input("Which color do you prefer (red, black, silver, white)?: ").lower()
            print(f"You selected {color}.")
            
    else:
        print("Sorry, we don't have this Phone available.") 


#====================== Specifications ====================================================
    if choice.lower() in ['1','2','3','apple iphone','redmi','samsung galaxy']:
        print("\nBELOW ARE YOUR PHONE SPECIFICATIONS.")
        if choice.lower() in ["1", "apple iphone"]:
            brand = "Apple iPhone"
        elif choice.lower() in ["2", "redmi"]:
            brand = "Redmi"
        elif choice.lower() in ["3", "samsung galaxy"]:
            brand = "Samsung Galaxy"
        
        print(f' Brand          :    {brand}')
        print(f' Model          :    {mod}')
        print(f' Color          :    {color}')
        print(" Ram             :  ",ram,"gb")
        print(" Variant         :  ",store,"gb")
        print(f" Display        :    {dis}")
        print(f' Resolution     :    {res}')
        print(f' Camera         :    {cam}')
        print(f' Battery        :    {bat}')
        print(f' Processor      :    {proc}')
        print(" Charger in box  :   Yes")
        print(' Storage         :  ',ram,'gb' ' ' 'and' ,store,'gb')
        print(f' Total_bill     :    {tot_price}rs')
        print("\nThank you for shopping with us! We hope to see you again. Have a great day!")
phone_store()
# Out:
# ********** WELCOME TO PYTHON STORE. **********
# Do you want phone? Type Yes or No:  yes
# Great! Select the phone from the below list.
# 1. Apple iPhone
# 2. Redmi
# 3. Samsung galaxy
# Which Brand do you prefer? :  Apple iphone
#  1.iPhone 15
#  2.iPhone 15 plus
#  3.iPhone 15 Pro
#  4.iPhone 15 Pro Max
# Which model in iphone will u prefer? iphone 15 pro max
#  About Phone
#  DISPLAY: 6.7 inches(17.00cm)Super Retina XDR OLED Display
#  RESOLUTION: 1179*2556px(FHD+)
#  CAMERA: Dual camera setup ,48MP + 12MP wide angle primary camera, 12MP front cam
#  BATTERY: 3349mAh, 20w fast charging
#  PROCESSOR: A16 Bionic chip
#
# VARIANT & RAM:
#   1.6gb + 256gb
#  2.6gb + 512gb
# What storage and ram phone you need to select:  2
# Available Colors: [Black, White, Red, Silver]
# Which color do you prefer ?:  white
# You selected white.
#
# BELOW ARE YOUR PHONE SPECIFICATIONS.
#  Brand          :    Apple iPhone
#  Model          :    Apple iPhone 15 Pro Max
#  Color          :    white
# ...
